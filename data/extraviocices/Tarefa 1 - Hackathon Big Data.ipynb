# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

path = '../raw'
path_lojas_atuais = f'{path}/lojas_atuais.csv'
path_faturamento_lojas_atuais = f'{path}/faturamento_lojas_atuais.csv'
path_cenarios_expansao = f'{path}/cenarios_expansao.csv'

lojas = pd.read_csv(path_lojas_atuais)
faturamento = pd.read_csv(path_faturamento_lojas_atuais)
expansao = pd.read_csv(path_cenarios_expansao)

# %%
# Arrumando o dataset para ficar do jeito que vamos treinar

# %%
path_ibge = 'tabelas_ibge_uteis/tabela392_csv.csv'

ibge = pd.read_csv(path_ibge, sep=';', encoding='latin1')

# %%
#ibge_values = ibge['ï»¿Areas'].values
#ibge.drop(['ï»¿Areas'], axis=1, inplace=True)
#ibge['Areas'] = pd.Series(ibge_values)
ibge.head()
# Out:
#      Column1   Column2   Column3   Column4      Column5      Column6  \
# 0  Ariquemes   50 123    28 179    21 943     1 207,58     1 349,38
# 1   Área 001    9 769     5 183     4 586     1 822,21     2 167,50
# 2   Área 002    9 076     5 406     3 670     1 131,17     1 323,46
# 3   Área 003   15 097     8 632     6 465       829,98       939,79
# 4   Área 004   16 180     8 959     7 222     1 231,68     1 286,37
#
#        Column7      Column8      Column9    Column10       Column11
# 0    1 025,48       700,00       800,00      510,00         1100023
# 1    1 432,02     1 000,00     1 200,00      800,00   1100023003001
# 2      847,90       650,00       800,00      510,00   1100023003002
# 3      683,35       550,00       693,00      510,00   1100023003003
# 4    1 163,84       700,00       800,00      510,00   1100023003004

# %%
ibge.columns
ibge = ibge.rename(columns={'Column5': 'renda_media', 'Column11': 'cod_ap'})
ibge.columns
# Out:
# Index(['Column1', 'Column2', 'Column3', 'Column4', 'renda_media', 'Column6',
#        'Column7', 'Column8', 'Column9', 'Column10', 'cod_ap'],
#       dtype='object')

# %%
ibge = ibge[['cod_ap', 'renda_media']]
ibge.head()
ibge.dtypes
# Out:
# cod_ap         object
# renda_media    object
# dtype: object

# %%
lojas.sample(30)

# IMPORTANTE -> FEATURES 13 a 15 ou todas estao presentes ou nenhuma esta presente -> tranformar em feature binaria posteriormente
# Out:
#       cod_loja         cod_ap  cod_municipio           feature_01  \
# 2740      3221  3550308005100        3550308  FEATURE_01_VALUE_08
# 2530      2981  3550308005110        3550308  FEATURE_01_VALUE_03
# 1167      1362  3511508003002        3511508                  NaN
# 1903      2243  3113701001001        3113701                  NaN
# 2685      3154  3131307005004        3131307  FEATURE_01_VALUE_08
# 1127      1313  5300108005042        5300108                  NaN
# 1544      1812  3105400003001        3105400                  NaN
# 2329      2750  3137205003002        3137205  FEATURE_01_VALUE_08
# 1380      1618  1100205004003        1100205                  NaN
# 1            2  5300108005004        5300108                  NaN
# 2859      3361  3136702005005        3136702  FEATURE_01_VALUE_03
# 719        834  1502707003002        1502707                  NaN
# 2443      2882  3205002005004        3205002  FEATURE_01_VALUE_10
# 1592      1873  3550308005173        3550308                  NaN
# 2371      2800  3304557005043        3304557                  NaN
# 715        830  2607208003002        2607208                  NaN
# 484        563  5107602005001        5107602                  NaN
# 2960      3486  3205309005007        3205309                  NaN
# 370        431  3550209003002        3550209                  NaN
# 1793      2108  3515509003003        3515509                  NaN
# 1607      1892  2613404001001        2613404                  NaN
# 497        579  3144102001001        3144102  FEATURE_01_VALUE_10
# 2423      2859  2304400005010        2304400  FEATURE_01_VALUE_10
# 1330      1557  3515152001001        3515152                  NaN
# 2327      2747  3151503003001        3151503                  NaN
# 1259      1472  3548708005016        3548708  FEATURE_01_VALUE_10
# 565        661  5105622001001        5105622                  NaN
# 1120      1305  4125506005001        4125506                  NaN
# 1086      1264  3550308005004        3550308                  NaN
# 2706      3179  3547809005016        3547809                  NaN
#
#                feature_02  feature_03  feature_04           feature_05  \
# 2740  FEATURE_02_VALUE_03        True       29.25  FEATURE_05_VALUE_07
# 2530  FEATURE_02_VALUE_03        True       12.50  FEATURE_05_VALUE_01
# 1167  FEATURE_02_VALUE_06       False       31.13  FEATURE_05_VALUE_03
# 1903  FEATURE_02_VALUE_04       False       30.54  FEATURE_05_VALUE_03
# 2685  FEATURE_02_VALUE_03        True       39.37  FEATURE_05_VALUE_03
# 1127  FEATURE_02_VALUE_02        True       32.09  FEATURE_05_VALUE_05
# 1544  FEATURE_02_VALUE_04       False       30.89  FEATURE_05_VALUE_03
# 2329  FEATURE_02_VALUE_06       False       40.57  FEATURE_05_VALUE_03
# 1380  FEATURE_02_VALUE_02        True       59.91  FEATURE_05_VALUE_05
# 1     FEATURE_02_VALUE_03        True       22.00  FEATURE_05_VALUE_03
# 2859  FEATURE_02_VALUE_02       False       10.00  FEATURE_05_VALUE_06
# 719   FEATURE_02_VALUE_06       False       31.51  FEATURE_05_VALUE_03
# 2443  FEATURE_02_VALUE_06        True       26.01  FEATURE_05_VALUE_02
# 1592  FEATURE_02_VALUE_02        True       51.27  FEATURE_05_VALUE_05
# 2371  FEATURE_02_VALUE_03        True       62.56  FEATURE_05_VALUE_03
# 715   FEATURE_02_VALUE_06       False       36.00  FEATURE_05_VALUE_03
# 484   FEATURE_02_VALUE_06       False       69.41  FEATURE_05_VALUE_03
# 2960  FEATURE_02_VALUE_06        True       26.00  FEATURE_05_VALUE_03
# 370   FEATURE_02_VALUE_02       False       30.80  FEATURE_05_VALUE_03
# 1793  FEATURE_02_VALUE_03       False       38.35  FEATURE_05_VALUE_03
# 1607  FEATURE_02_VALUE_02       False       21.67  FEATURE_05_VALUE_03
# 497   FEATURE_02_VALUE_04       False       36.50  FEATURE_05_VALUE_03
# 2423  FEATURE_02_VALUE_03       False       28.80  FEATURE_05_VALUE_05
# 1330  FEATURE_02_VALUE_06       False       33.15  FEATURE_05_VALUE_03
# 2327  FEATURE_02_VALUE_06       False       35.36  FEATURE_05_VALUE_03
# 1259  FEATURE_02_VALUE_03        True       38.09  FEATURE_05_VALUE_06
# 565   FEATURE_02_VALUE_04       False       29.70  FEATURE_05_VALUE_03
# 1120  FEATURE_02_VALUE_02        True       20.60  FEATURE_05_VALUE_06
# 1086  FEATURE_02_VALUE_02        True       30.30  FEATURE_05_VALUE_03
# 2706  FEATURE_02_VALUE_03        True       24.85  FEATURE_05_VALUE_06
#
#       feature_06  feature_07  ...   feature_09  feature_10  \
# 2740           8    0.190102  ...  5593.905463    2.815883
# 2530           4    0.190102  ...  5593.905463    2.815883
# 1167           5    0.179395  ...    21.368656    2.215232
# 1903           2    0.235675  ...     4.115097    5.007261
# 2685           5    0.136679  ...   111.147986    3.497251
# 1127           5    0.215967  ...  1562.674817    3.670883
# 1544           3    0.146770  ...    10.259349    3.197953
# 2329           3    0.146187  ...    20.068763    5.976453
# 1380          13    0.265100  ...   228.918801    2.187975
# 1             27    0.215967  ...  1562.674817    3.670883
# 2859           3    0.104639  ...   260.195927    2.701320
# 719            3    0.151102  ...    15.770619    2.155405
# 2443           1    0.118749  ...   231.373665    4.120517
# 1592          15    0.190102  ...  5593.905463    2.815883
# 2371          10    0.098399  ...  2972.139303    2.964504
# 715            7    0.156880  ...    30.616304    3.284396
# 484            8    0.231192  ...   117.417535    3.250975
# 2960           2    0.118749  ...   231.355174    7.305936
# 370           17    0.272225  ...     7.560554    3.051665
# 1793           4    0.118039  ...    33.419936    4.403993
# 1607           2    0.141745  ...     6.270098    4.917630
# 497            8    0.151853  ...     5.907283    4.758053
# 2423           3    0.153550  ...  1206.049904    2.276948
# 1330           2    0.158089  ...     5.915294    5.373166
# 2327           3    0.154921  ...    13.496157    5.869406
# 1259           3    0.190102  ...   374.342337    2.693026
# 565            4    0.276460  ...     9.804677    3.792332
# 1120           1    0.168922  ...   115.958848    2.349821
# 1086           6    0.190102  ...  5593.905463    2.815883
# 2706           9    0.190102  ...   357.888940    8.589009
#
#                feature_11           feature_12 feature_13  feature_14  \
# 2740  FEATURE_11_VALUE_01  FEATURE_12_VALUE_02       98.6        89.5
# 2530                  NaN                  NaN        NaN         NaN
# 1167                  NaN                  NaN        NaN         NaN
# 1903                  NaN                  NaN        NaN         NaN
# 2685                  NaN                  NaN        NaN         NaN
# 1127                  NaN                  NaN      100.0        88.8
# 1544                  NaN                  NaN        NaN         NaN
# 2329                  NaN                  NaN        NaN         NaN
# 1380  FEATURE_11_VALUE_02  FEATURE_12_VALUE_01      100.0        83.1
# 1                     NaN                  NaN        NaN         NaN
# 2859                  NaN                  NaN        NaN         NaN
# 719   FEATURE_11_VALUE_06  FEATURE_12_VALUE_02        NaN         NaN
# 2443                  NaN                  NaN        NaN         NaN
# 1592  FEATURE_11_VALUE_07  FEATURE_12_VALUE_01        NaN         NaN
# 2371                  NaN                  NaN        NaN         NaN
# 715                   NaN                  NaN        NaN         NaN
# 484                   NaN                  NaN      100.0        60.6
# 2960                  NaN                  NaN        NaN         NaN
# 370                   NaN                  NaN        NaN         NaN
# 1793                  NaN                  NaN       87.2        92.4
# 1607  FEATURE_11_VALUE_06  FEATURE_12_VALUE_02        NaN         NaN
# 497                   NaN                  NaN      100.0        84.0
# 2423                  NaN                  NaN        NaN         NaN
# 1330                  NaN                  NaN        NaN         NaN
# 2327                  NaN                  NaN        NaN         NaN
# 1259  FEATURE_11_VALUE_01  FEATURE_12_VALUE_02        NaN         NaN
# 565                   NaN                  NaN      100.0        95.8
# 1120  FEATURE_11_VALUE_06  FEATURE_12_VALUE_02        NaN         NaN
# 1086                  NaN                  NaN        NaN         NaN
# 2706                  NaN                  NaN        NaN         NaN
#
#       feature_15  feature_16  feature_17  feature_18
# 2740        93.3       100.0        94.4        88.9
# 2530         NaN         NaN         NaN         NaN
# 1167         NaN         NaN         NaN         NaN
# 1903         NaN         NaN         NaN         NaN
# 2685         NaN         NaN         NaN         NaN
# 1127       100.0       100.0        45.7        78.5
# 1544         NaN         NaN         NaN         NaN
# 2329         NaN         NaN         NaN         NaN
# 1380       100.0       100.0        98.5        96.7
# 1            NaN         NaN         NaN         NaN
# 2859         NaN         NaN         NaN         NaN
# 719          NaN         NaN         NaN         NaN
# 2443         NaN         NaN         NaN         NaN
# 1592         NaN         NaN         NaN         NaN
# 2371         NaN         NaN         NaN         NaN
# 715          NaN         NaN         NaN         NaN
# 484        100.0       100.0        60.2        78.9
# 2960         NaN         NaN         NaN         NaN
# 370          NaN         NaN         NaN         NaN
# 1793       100.0       100.0        46.7        76.2
# 1607         NaN         NaN         NaN         NaN
# 497        100.0       100.0        97.3        97.0
# 2423         NaN         NaN         NaN         NaN
# 1330         NaN         NaN         NaN         NaN
# 2327         NaN         NaN         NaN         NaN
# 1259         NaN         NaN         NaN         NaN
# 565        100.0       100.0       100.0        99.3
# 1120         NaN         NaN         NaN         NaN
# 1086         NaN         NaN         NaN         NaN
# 2706         NaN         NaN         NaN         NaN
#
# [30 rows x 21 columns]

# %%
lojas.isnull().sum()
print(lojas.dtypes)
# Out:
# cod_loja           int64
# cod_ap             int64
# cod_municipio      int64
# feature_01        object
# feature_02        object
# feature_03          bool
# feature_04       float64
# feature_05        object
# feature_06         int64
# feature_07       float64
# feature_08       float64
# feature_09       float64
# feature_10       float64
# feature_11        object
# feature_12        object
# feature_13       float64
# feature_14       float64
# feature_15       float64
# feature_16       float64
# feature_17       float64
# feature_18       float64
# dtype: object

# %%
# mudar os types:

# observacao feat 12 e binaria na vdd mas vamos deixar assim, pq
# ainda teremos que lidar com missing values, entao ter 3 categorias
# na vdd
lojas['cod_loja'] = lojas['cod_loja'].astype(str)
lojas['cod_ap'] = lojas['cod_ap'].astype(str)
lojas['cod_municipio'] = lojas['cod_municipio'].astype(str)

# %%
print(lojas.shape)
print(lojas.info())
print(lojas.duplicated().any())
# Out:
# (3130, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3130 entries, 0 to 3129
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cod_loja       3130 non-null   object
#  1   cod_ap         3130 non-null   object
#  2   cod_municipio  3130 non-null   object
#  3   feature_01     1171 non-null   object
#  4   feature_02     3130 non-null   object
#  5   feature_03     3130 non-null   bool
#  6   feature_04     3130 non-null   float64
#  7   feature_05     3130 non-null   object
#  8   feature_06     3130 non-null   int64
#  9   feature_07     3130 non-null   float64
#  10  feature_08     3130 non-null   float64
#  11  feature_09     3130 non-null   float64
#  12  feature_10     3130 non-null   float64
#  13  feature_11     245 non-null    object
#  14  feature_12     245 non-null    object
#  15  feature_13     874 non-null    float64
#  16  feature_14     874 non-null    float64
#  17  feature_15     874 non-null    float64
#  18  feature_16     874 non-null    float64
#  19  feature_17     874 non-null    float64
#  20  feature_18     874 non-null    float64
# dtypes: bool(1), float64(11), int64(1), object(8)
# memory usage: 492.2+ KB
# None
# False

# %%
#  lojas onde foi inputado -1 (nao se conhece dados geograficos)
lojas[lojas['cod_ap'] == '-1']
# Out:
#      cod_loja cod_ap cod_municipio           feature_01           feature_02  \
# 178      3391     -1            -1  FEATURE_01_VALUE_10  FEATURE_02_VALUE_03
# 475       688     -1            -1                  NaN  FEATURE_02_VALUE_04
# 605       708     -1            -1  FEATURE_01_VALUE_08  FEATURE_02_VALUE_02
# 617       721     -1            -1                  NaN  FEATURE_02_VALUE_04
# 652       760     -1            -1                  NaN  FEATURE_02_VALUE_03
# ...       ...    ...           ...                  ...                  ...
# 3097     3646     -1            -1                  NaN  FEATURE_02_VALUE_03
# 3099     3648     -1            -1  FEATURE_01_VALUE_08  FEATURE_02_VALUE_03
# 3101     3651     -1            -1  FEATURE_01_VALUE_10  FEATURE_02_VALUE_04
# 3106     3657     -1            -1  FEATURE_01_VALUE_03  FEATURE_02_VALUE_06
# 3117     3671     -1            -1                  NaN  FEATURE_02_VALUE_03
#
#       feature_03  feature_04           feature_05  feature_06  feature_07  \
# 178         True       32.00  FEATURE_05_VALUE_06           6    0.107963
# 475        False       34.50  FEATURE_05_VALUE_03           3    0.260188
# 605         True       46.50  FEATURE_05_VALUE_07           4    0.168922
# 617         True       35.30  FEATURE_05_VALUE_03           5    0.215967
# 652        False       48.04  FEATURE_05_VALUE_05           8    0.143917
# ...          ...         ...                  ...         ...         ...
# 3097        True       33.30  FEATURE_05_VALUE_05           8    0.215967
# 3099        True       47.28  FEATURE_05_VALUE_05           5    0.215967
# 3101        True       28.34  FEATURE_05_VALUE_03           3    0.215967
# 3106        True       12.00  FEATURE_05_VALUE_06           0    0.107963
# 3117       False       35.00  FEATURE_05_VALUE_03           4    0.190896
#
#       ...   feature_09  feature_10           feature_11           feature_12  \
# 178   ...  1355.486603    4.142294                  NaN                  NaN
# 475   ...     6.502798    4.091820                  NaN                  NaN
# 605   ...   115.958848    2.349821  FEATURE_11_VALUE_01  FEATURE_12_VALUE_02
# 617   ...  1562.674817    3.670883                  NaN                  NaN
# 652   ...   201.530115    3.269826                  NaN                  NaN
# ...   ...          ...         ...                  ...                  ...
# 3097  ...  1562.674817    3.670883                  NaN                  NaN
# 3099  ...  1562.674817    3.670883  FEATURE_11_VALUE_01  FEATURE_12_VALUE_01
# 3101  ...  1562.674817    3.670883  FEATURE_11_VALUE_06  FEATURE_12_VALUE_01
# 3106  ...   106.561828    2.439713                  NaN                  NaN
# 3117  ...   214.680500    1.341227                  NaN                  NaN
#
#      feature_13  feature_14  feature_15  feature_16  feature_17  feature_18
# 178         NaN         NaN         NaN         NaN         NaN         NaN
# 475         NaN         NaN         NaN         NaN         NaN         NaN
# 605        98.8        70.1        80.0       100.0        81.1        85.8
# 617       100.0        73.1       100.0       100.0        88.3        91.3
# 652       100.0        83.8         0.0       100.0        94.8        92.4
# ...         ...         ...         ...         ...         ...         ...
# 3097        NaN         NaN         NaN         NaN         NaN         NaN
# 3099        NaN         NaN         NaN         NaN         NaN         NaN
# 3101        NaN         NaN         NaN         NaN         NaN         NaN
# 3106        NaN         NaN         NaN         NaN         NaN         NaN
# 3117        NaN         NaN         NaN         NaN         NaN         NaN
#
# [151 rows x 21 columns]

# %%
faturamento.head(15)
# Out:
#     cod_loja   ano  mes categoria   qtde   receita
# 0          1  2016    1  CATEG_01  301.0   9164.86
# 1          1  2016    2  CATEG_01  187.0   8175.55
# 2          1  2016    3  CATEG_01  242.0  10521.67
# 3          1  2016    4  CATEG_01  104.0   4560.91
# 4          1  2016    5  CATEG_01  100.0   4263.30
# 5          1  2016    6  CATEG_01  108.0   4741.36
# 6          1  2016    7  CATEG_01  111.0   5604.77
# 7          1  2016    8  CATEG_01   86.0   3987.35
# 8          1  2016    9  CATEG_01  148.0   5543.12
# 9          1  2016   10  CATEG_01  147.0   4996.06
# 10         1  2016   11  CATEG_01  102.0   3090.26
# 11         1  2016   12  CATEG_01  110.0   3650.70
# 12         1  2017    1  CATEG_01  114.0   3584.10
# 13         1  2017    2  CATEG_01   74.0   2261.09
# 14         1  2017    3  CATEG_01  125.0   3461.04

# %%
print(faturamento.shape)
print(faturamento.info())
print(faturamento.duplicated().any())
# Out:
# (1003094, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003094 entries, 0 to 1003093
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   cod_loja   1003094 non-null  int64
#  1   ano        1003094 non-null  int64
#  2   mes        1003094 non-null  int64
#  3   categoria  1003094 non-null  object
#  4   qtde       1003094 non-null  float64
#  5   receita    1003094 non-null  float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 45.9+ MB
# None
# False

# %%
expansao.head()
# Out:
#    cod_loja         cod_ap  cod_municipio           feature_01  \
# 0        10  2933307005008        2933307  FEATURE_01_VALUE_08
# 1        13  2916401003002        2916401  FEATURE_01_VALUE_10
# 2        16  2928703003003        2928703                  NaN
# 3        21  2906006003001        2906006                  NaN
# 4        28  3550308005058        3550308  FEATURE_01_VALUE_10
#
#             feature_02  feature_03  feature_04           feature_05  \
# 0  FEATURE_02_VALUE_02       False       50.00  FEATURE_05_VALUE_03
# 1  FEATURE_02_VALUE_04       False       41.00  FEATURE_05_VALUE_03
# 2  FEATURE_02_VALUE_04       False       42.12  FEATURE_05_VALUE_05
# 3  FEATURE_02_VALUE_04       False       30.00  FEATURE_05_VALUE_03
# 4  FEATURE_02_VALUE_02        True       44.31  FEATURE_05_VALUE_03
#
#    feature_06  feature_07  ...   feature_09  feature_10           feature_11  \
# 0           6    0.134654  ...   116.194058    2.913498  FEATURE_11_VALUE_01
# 1           4    0.116662  ...    26.345742    1.312612                  NaN
# 2           2    0.104162  ...    35.362788    1.969512                  NaN
# 3           6    0.132954  ...     9.862757    1.383681                  NaN
# 4           8    0.190102  ...  5593.905463    2.815883  FEATURE_11_VALUE_02
#
#             feature_12 feature_13  feature_14  feature_15  feature_16  \
# 0  FEATURE_12_VALUE_01      100.0        93.4       100.0       100.0
# 1                  NaN       84.3        77.5       100.0       100.0
# 2                  NaN        NaN         NaN         NaN         NaN
# 3                  NaN       85.0        76.9       100.0       100.0
# 4  FEATURE_12_VALUE_01        NaN         NaN         NaN         NaN
#
#    feature_17  feature_18
# 0        71.7        88.8
# 1        63.5        78.8
# 2         NaN         NaN
# 3       100.0        92.9
# 4         NaN         NaN
#
# [5 rows x 21 columns]

# %%
print(expansao.shape)
print(expansao.info())
print(expansao.duplicated().any())
# Out:
# (553, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cod_loja       553 non-null    int64
#  1   cod_ap         553 non-null    int64
#  2   cod_municipio  553 non-null    int64
#  3   feature_01     189 non-null    object
#  4   feature_02     553 non-null    object
#  5   feature_03     553 non-null    bool
#  6   feature_04     553 non-null    float64
#  7   feature_05     553 non-null    object
#  8   feature_06     553 non-null    int64
#  9   feature_07     553 non-null    float64
#  10  feature_08     553 non-null    float64
#  11  feature_09     553 non-null    float64
#  12  feature_10     553 non-null    float64
#  13  feature_11     41 non-null     object
#  14  feature_12     41 non-null     object
#  15  feature_13     159 non-null    float64
#  16  feature_14     159 non-null    float64
#  17  feature_15     159 non-null    float64
#  18  feature_16     159 non-null    float64
#  19  feature_17     159 non-null    float64
#  20  feature_18     159 non-null    float64
# dtypes: bool(1), float64(11), int64(4), object(5)
# memory usage: 87.1+ KB
# None
# False

# %%
faturamento['cod_loja'].nunique()
# Out:
# 3130

# %%
len(lojas)
# Out:
# 3130

# %%
len(expansao)
# Out:
# 553

# %%
faturamento.isnull().values.any()
# Out:
# False

# %%
faturamento.describe()
# Out:
#            cod_loja           ano           mes          qtde       receita
# count  1.003094e+06  1.003094e+06  1.003094e+06  1.003094e+06  1.003094e+06
# mean   1.801101e+03  2.016502e+03  6.511972e+00  2.043899e+02  9.334457e+03
# std    1.054476e+03  4.999960e-01  3.454766e+00  3.482261e+02  2.367026e+04
# min    1.000000e+00  2.016000e+03  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.830000e+02  2.016000e+03  4.000000e+00  2.000000e+01  6.005375e+02
# 50%    1.784000e+03  2.017000e+03  7.000000e+00  7.700000e+01  2.252815e+03
# 75%    2.711000e+03  2.017000e+03  1.000000e+01  2.490000e+02  7.675568e+03
# max    3.687000e+03  2.017000e+03  1.200000e+01  1.216000e+04  9.751064e+05

# %%
faturamento.head()
# Out:
#    cod_loja   ano  mes categoria   qtde   receita
# 0         1  2016    1  CATEG_01  301.0   9164.86
# 1         1  2016    2  CATEG_01  187.0   8175.55
# 2         1  2016    3  CATEG_01  242.0  10521.67
# 3         1  2016    4  CATEG_01  104.0   4560.91
# 4         1  2016    5  CATEG_01  100.0   4263.30

# %%
# colocar as categorias para cada mes

cat_concat_list = []
loja_ano_mes_cont_list = []
i = 0
for ((cod_loja, ano, mes), gp) in faturamento.groupby(['cod_loja', 'ano', 'mes']):
    month_categories = pd.Series(gp['qtde'].values, index=gp['categoria'].values).to_dict()
    cat_df = pd.DataFrame(month_categories, index=[i])
    cat_concat_list.append(cat_df)
    loja_ano_mes_cont_list.append({'cod_loja':cod_loja, 'ano':ano, 'mes':mes})
    i += 1 
cat_full = pd.concat([*cat_concat_list])
loja_ano_mes_cont_full = pd.DataFrame(loja_ano_mes_cont_list)
loja_ano_mes_cont_full.head(10)
# Out:
#    cod_loja   ano  mes
# 0         1  2016    1
# 1         1  2016    2
# 2         1  2016    3
# 3         1  2016    4
# 4         1  2016    5
# 5         1  2016    6
# 6         1  2016    7
# 7         1  2016    8
# 8         1  2016    9
# 9         1  2016   10

# %%
loja_ano_mes_cont_full.shape
# Out:
# (73644, 3)

# %%
cat_full.shape
# Out:
# (73644, 16)

# %%
faturamento = faturamento.groupby(['cod_loja', 'ano', 'mes'])[['qtde', 'receita']].sum().reset_index(drop = True)
faturamento.shape
# Out:
# (73644, 2)

# %%
faturamento = pd.concat([loja_ano_mes_cont_full, faturamento, cat_full], axis=1)
faturamento.shape
# Out:
# (73644, 21)

# %%
faturamento.head()
# Out:
#    cod_loja   ano  mes     qtde    receita  CATEG_01  CATEG_02  CATEG_03  \
# 0         1  2016    1  13034.0  441833.37     301.0     137.0    1469.0
# 1         1  2016    2  11411.0  395340.22     187.0     193.0    1579.0
# 2         1  2016    3  15030.0  587810.18     242.0      71.0    1935.0
# 3         1  2016    4  12726.0  534618.84     104.0      74.0    1466.0
# 4         1  2016    5  13978.0  595477.92     100.0      84.0    1576.0
#
#    CATEG_04  CATEG_05  ...  CATEG_07  CATEG_08  CATEG_09  CATEG_10  CATEG_11  \
# 0     251.0    1155.0  ...    1424.0     139.0    1357.0     273.0    3820.0
# 1     215.0    1213.0  ...    1153.0     135.0    1461.0     356.0    2637.0
# 2     280.0    1460.0  ...    1639.0     296.0    2270.0     428.0    4251.0
# 3     304.0    1356.0  ...    1405.0     547.0    1644.0     413.0    3688.0
# 4     308.0    1777.0  ...    1194.0     422.0    1682.0     509.0    4345.0
#
#    CATEG_12  CATEG_13  CATEG_14  CATEG_15  CATEG_16
# 0    1846.0     288.0      24.0       NaN       NaN
# 1    1633.0     262.0      24.0       NaN       NaN
# 2    1526.0     145.0     320.0       NaN       NaN
# 3    1384.0     190.0       7.0       NaN       NaN
# 4    1537.0     107.0     146.0       NaN       NaN
#
# [5 rows x 21 columns]

# %%
faturamento.to_csv('../final/estrabico.csv')

# %%
# todas as combinacoes possiveis de loja, ano, mes
# garantir que nao vai faltar nada

from itertools import product

loja_unique = faturamento['cod_loja'].unique()
ano_unique = faturamento['ano'].unique()
mes_unique = faturamento['mes'].unique()

all_combinations = np.vstack(list(product(loja_unique, ano_unique, mes_unique)))

combinations_faturamento = pd.DataFrame(all_combinations, columns=['cod_loja', 'ano', 'mes'])

# %%
combinations_faturamento = combinations_faturamento.sort_values(by=['cod_loja', 'ano', 'mes'])

# %%
faturamento = pd.merge(faturamento, combinations_faturamento, on=['cod_loja', 'ano', 'mes'], how='right')

# %%
faturamento.head()
# Out:
#    cod_loja   ano  mes     qtde    receita  CATEG_01  CATEG_02  CATEG_03  \
# 0         1  2016    1  13034.0  441833.37     301.0     137.0    1469.0
# 1         1  2016    2  11411.0  395340.22     187.0     193.0    1579.0
# 2         1  2016    3  15030.0  587810.18     242.0      71.0    1935.0
# 3         1  2016    4  12726.0  534618.84     104.0      74.0    1466.0
# 4         1  2016    5  13978.0  595477.92     100.0      84.0    1576.0
#
#    CATEG_04  CATEG_05  ...  CATEG_07  CATEG_08  CATEG_09  CATEG_10  CATEG_11  \
# 0     251.0    1155.0  ...    1424.0     139.0    1357.0     273.0    3820.0
# 1     215.0    1213.0  ...    1153.0     135.0    1461.0     356.0    2637.0
# 2     280.0    1460.0  ...    1639.0     296.0    2270.0     428.0    4251.0
# 3     304.0    1356.0  ...    1405.0     547.0    1644.0     413.0    3688.0
# 4     308.0    1777.0  ...    1194.0     422.0    1682.0     509.0    4345.0
#
#    CATEG_12  CATEG_13  CATEG_14  CATEG_15  CATEG_16
# 0    1846.0     288.0      24.0       NaN       NaN
# 1    1633.0     262.0      24.0       NaN       NaN
# 2    1526.0     145.0     320.0       NaN       NaN
# 3    1384.0     190.0       7.0       NaN       NaN
# 4    1537.0     107.0     146.0       NaN       NaN
#
# [5 rows x 21 columns]

# %%
faturamento.loc[faturamento['ano'] == 2016, 'mes_cont'] = faturamento.loc[faturamento['ano'] == 2016, 'mes']
faturamento.loc[faturamento['ano'] == 2017, 'mes_cont'] = 12 + faturamento.loc[faturamento['ano'] == 2017, 'mes']

# %%
print(faturamento['CATEG_08'].max())
print(faturamento['CATEG_08'].mean())
print(faturamento['CATEG_07'].max())
print(faturamento['CATEG_07'].mean())
print(faturamento['CATEG_06'].max())
print(faturamento['CATEG_06'].mean())
print(faturamento['CATEG_05'].max())
print(faturamento['CATEG_05'].mean())
print(faturamento['CATEG_04'].max())
print(faturamento['CATEG_04'].mean())
print(faturamento['CATEG_03'].max())
print(faturamento['CATEG_03'].mean())
print(faturamento['CATEG_02'].max())
print(faturamento['CATEG_02'].mean())
print(faturamento['CATEG_01'].max())
print(faturamento['CATEG_01'].mean())
# Out:
# 2775.0
# 86.58908660195232
# 4639.0
# 347.8516858815062
# 606.0
# 28.146539320607864
# 8728.0
# 407.18681930525
# 1270.0
# 42.09782667975567
# 3199.0
# 152.8395371891848
# 193.0
# 5.058140857890545
# 1012.0
# 33.2709123141961

# %%
faturamento['cod_loja'] = faturamento['cod_loja'].astype(str)

# %%
faturamento = pd.merge(faturamento, lojas, on='cod_loja', how='inner')
faturamento.head(12)
# Out:
#    cod_loja   ano  mes     qtde     receita  CATEG_01  CATEG_02  CATEG_03  \
# 0         1  2016    1  13034.0   441833.37     301.0     137.0    1469.0
# 1         1  2016    2  11411.0   395340.22     187.0     193.0    1579.0
# 2         1  2016    3  15030.0   587810.18     242.0      71.0    1935.0
# 3         1  2016    4  12726.0   534618.84     104.0      74.0    1466.0
# 4         1  2016    5  13978.0   595477.92     100.0      84.0    1576.0
# 5         1  2016    6  14693.0   589947.05     108.0      96.0    1726.0
# 6         1  2016    7  13570.0   563814.03     111.0      90.0    1553.0
# 7         1  2016    8  13889.0   625181.36      86.0      81.0    1667.0
# 8         1  2016    9  13309.0   583509.12     148.0      90.0    1426.0
# 9         1  2016   10  14709.0   611797.30     147.0      79.0    1702.0
# 10        1  2016   11  19162.0   876921.63     102.0      75.0    1777.0
# 11        1  2016   12  26963.0  1257613.00     110.0     100.0    2294.0
#
#     CATEG_04  CATEG_05  ...  feature_09  feature_10  feature_11  feature_12  \
# 0      251.0    1155.0  ...  115.958848    2.349821         NaN         NaN
# 1      215.0    1213.0  ...  115.958848    2.349821         NaN         NaN
# 2      280.0    1460.0  ...  115.958848    2.349821         NaN         NaN
# 3      304.0    1356.0  ...  115.958848    2.349821         NaN         NaN
# 4      308.0    1777.0  ...  115.958848    2.349821         NaN         NaN
# 5      327.0    1599.0  ...  115.958848    2.349821         NaN         NaN
# 6      325.0    1329.0  ...  115.958848    2.349821         NaN         NaN
# 7      504.0    1238.0  ...  115.958848    2.349821         NaN         NaN
# 8      295.0    1374.0  ...  115.958848    2.349821         NaN         NaN
# 9      315.0    1983.0  ...  115.958848    2.349821         NaN         NaN
# 10     391.0    2913.0  ...  115.958848    2.349821         NaN         NaN
# 11     745.0    4768.0  ...  115.958848    2.349821         NaN         NaN
#
#     feature_13  feature_14  feature_15  feature_16  feature_17  feature_18
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN         NaN
#
# [12 rows x 42 columns]

# %%
faturamento.shape
# Out:
# (73644, 42)

# %%
faturamento.isnull().sum()
# Out:
# cod_loja             0
# ano                  0
# mes                  0
# qtde                 0
# receita              0
# CATEG_01           314
# CATEG_02         20910
# CATEG_03             7
# CATEG_04           300
# CATEG_05             6
# CATEG_06           667
# CATEG_07             3
# CATEG_08           193
# CATEG_09             5
# CATEG_10            53
# CATEG_11             5
# CATEG_12             7
# CATEG_13          2677
# CATEG_14          3713
# CATEG_15         72708
# CATEG_16         73642
# mes_cont             0
# cod_ap               0
# cod_municipio        0
# feature_01       46672
# feature_02           0
# feature_03           0
# feature_04           0
# feature_05           0
# feature_06           0
# feature_07           0
# feature_08           0
# feature_09           0
# feature_10           0
# feature_11       67795
# feature_12       67795
# feature_13       52695
# feature_14       52695
# feature_15       52695
# feature_16       52695
# feature_17       52695
# feature_18       52695
# dtype: int64

# %%
faturamento['cod_ap'] = faturamento['cod_ap'].astype(str)

# %%
faturamento = pd.merge(faturamento, ibge, on='cod_ap', how='left')
faturamento.head(20)
# Out:
#    cod_loja   ano  mes     qtde     receita  CATEG_01  CATEG_02  CATEG_03  \
# 0         1  2016    1  13034.0   441833.37     301.0     137.0    1469.0
# 1         1  2016    2  11411.0   395340.22     187.0     193.0    1579.0
# 2         1  2016    3  15030.0   587810.18     242.0      71.0    1935.0
# 3         1  2016    4  12726.0   534618.84     104.0      74.0    1466.0
# 4         1  2016    5  13978.0   595477.92     100.0      84.0    1576.0
# 5         1  2016    6  14693.0   589947.05     108.0      96.0    1726.0
# 6         1  2016    7  13570.0   563814.03     111.0      90.0    1553.0
# 7         1  2016    8  13889.0   625181.36      86.0      81.0    1667.0
# 8         1  2016    9  13309.0   583509.12     148.0      90.0    1426.0
# 9         1  2016   10  14709.0   611797.30     147.0      79.0    1702.0
# 10        1  2016   11  19162.0   876921.63     102.0      75.0    1777.0
# 11        1  2016   12  26963.0  1257613.00     110.0     100.0    2294.0
# 12        1  2017    1  10065.0   404108.77     114.0     105.0    1508.0
# 13        1  2017    2  11107.0   483610.18      74.0      89.0    1917.0
# 14        1  2017    3  13958.0   626291.59     125.0      95.0    2417.0
# 15        1  2017    4  12439.0   612062.60     127.0     117.0    1655.0
# 16        1  2017    5  15084.0   748281.98     117.0     112.0    1706.0
# 17        1  2017    6  14286.0   700312.65     139.0     137.0    1892.0
# 18        1  2017    7  13704.0   646369.23     601.0      61.0    1536.0
# 19        1  2017    8  15884.0   757850.68     327.0      15.0    3199.0
#
#     CATEG_04  CATEG_05  ...  feature_10  feature_11  feature_12  feature_13  \
# 0      251.0    1155.0  ...    2.349821         NaN         NaN         NaN
# 1      215.0    1213.0  ...    2.349821         NaN         NaN         NaN
# 2      280.0    1460.0  ...    2.349821         NaN         NaN         NaN
# 3      304.0    1356.0  ...    2.349821         NaN         NaN         NaN
# 4      308.0    1777.0  ...    2.349821         NaN         NaN         NaN
# 5      327.0    1599.0  ...    2.349821         NaN         NaN         NaN
# 6      325.0    1329.0  ...    2.349821         NaN         NaN         NaN
# 7      504.0    1238.0  ...    2.349821         NaN         NaN         NaN
# 8      295.0    1374.0  ...    2.349821         NaN         NaN         NaN
# 9      315.0    1983.0  ...    2.349821         NaN         NaN         NaN
# 10     391.0    2913.0  ...    2.349821         NaN         NaN         NaN
# 11     745.0    4768.0  ...    2.349821         NaN         NaN         NaN
# 12     225.0    1310.0  ...    2.349821         NaN         NaN         NaN
# 13     258.0    1437.0  ...    2.349821         NaN         NaN         NaN
# 14     311.0    1846.0  ...    2.349821         NaN         NaN         NaN
# 15     260.0    1535.0  ...    2.349821         NaN         NaN         NaN
# 16     282.0    2270.0  ...    2.349821         NaN         NaN         NaN
# 17     289.0    1937.0  ...    2.349821         NaN         NaN         NaN
# 18     304.0    1856.0  ...    2.349821         NaN         NaN         NaN
# 19     498.0    1749.0  ...    2.349821         NaN         NaN         NaN
#
#     feature_14  feature_15  feature_16  feature_17  feature_18  renda_media
# 0          NaN         NaN         NaN         NaN         NaN    1 429,93
# 1          NaN         NaN         NaN         NaN         NaN    1 429,93
# 2          NaN         NaN         NaN         NaN         NaN    1 429,93
# 3          NaN         NaN         NaN         NaN         NaN    1 429,93
# 4          NaN         NaN         NaN         NaN         NaN    1 429,93
# 5          NaN         NaN         NaN         NaN         NaN    1 429,93
# 6          NaN         NaN         NaN         NaN         NaN    1 429,93
# 7          NaN         NaN         NaN         NaN         NaN    1 429,93
# 8          NaN         NaN         NaN         NaN         NaN    1 429,93
# 9          NaN         NaN         NaN         NaN         NaN    1 429,93
# 10         NaN         NaN         NaN         NaN         NaN    1 429,93
# 11         NaN         NaN         NaN         NaN         NaN    1 429,93
# 12         NaN         NaN         NaN         NaN         NaN    1 429,93
# 13         NaN         NaN         NaN         NaN         NaN    1 429,93
# 14         NaN         NaN         NaN         NaN         NaN    1 429,93
# 15         NaN         NaN         NaN         NaN         NaN    1 429,93
# 16         NaN         NaN         NaN         NaN         NaN    1 429,93
# 17         NaN         NaN         NaN         NaN         NaN    1 429,93
# 18         NaN         NaN         NaN         NaN         NaN    1 429,93
# 19         NaN         NaN         NaN         NaN         NaN    1 429,93
#
# [20 rows x 43 columns]

# %%
faturamento.isnull().sum()
# Out:
# cod_loja             0
# ano                  0
# mes                  0
# qtde                 0
# receita              0
# CATEG_01           314
# CATEG_02         20910
# CATEG_03             7
# CATEG_04           300
# CATEG_05             6
# CATEG_06           667
# CATEG_07             3
# CATEG_08           193
# CATEG_09             5
# CATEG_10            53
# CATEG_11             5
# CATEG_12             7
# CATEG_13          2677
# CATEG_14          3713
# CATEG_15         72708
# CATEG_16         73642
# mes_cont             0
# cod_ap               0
# cod_municipio        0
# feature_01       46672
# feature_02           0
# feature_03           0
# feature_04           0
# feature_05           0
# feature_06           0
# feature_07           0
# feature_08           0
# feature_09           0
# feature_10           0
# feature_11       67795
# feature_12       67795
# feature_13       52695
# feature_14       52695
# feature_15       52695
# feature_16       52695
# feature_17       52695
# feature_18       52695
# renda_media      17925
# dtype: int64

# %%
faturamento.dtypes
# Out:
# cod_loja          object
# ano                int64
# mes                int64
# qtde             float64
# receita          float64
# CATEG_01         float64
# CATEG_02         float64
# CATEG_03         float64
# CATEG_04         float64
# CATEG_05         float64
# CATEG_06         float64
# CATEG_07         float64
# CATEG_08         float64
# CATEG_09         float64
# CATEG_10         float64
# CATEG_11         float64
# CATEG_12         float64
# CATEG_13         float64
# CATEG_14         float64
# CATEG_15         float64
# CATEG_16         float64
# mes_cont         float64
# cod_ap            object
# cod_municipio     object
# feature_01        object
# feature_02        object
# feature_03          bool
# feature_04       float64
# feature_05        object
# feature_06         int64
# feature_07       float64
# feature_08       float64
# feature_09       float64
# feature_10       float64
# feature_11        object
# feature_12        object
# feature_13       float64
# feature_14       float64
# feature_15       float64
# feature_16       float64
# feature_17       float64
# feature_18       float64
# renda_media       object
# dtype: object

# %%
faturamento.shape
# Out:
# (73644, 43)

# %%
faturamento['cod_ap'].nunique()
# Out:
# 2349

# %%
faturamento['cod_municipio'].nunique()
# Out:
# 1489

# %%
faturamento['renda_media'] = faturamento['renda_media'].astype(str).str.translate({32:None, 44:46}).astype(float)
faturamento['ano'] = faturamento['ano'].astype(str)
faturamento['mes'] = faturamento['mes'].astype(str)
faturamento.dtypes
# Out:
# cod_loja          object
# ano               object
# mes               object
# qtde             float64
# receita          float64
# CATEG_01         float64
# CATEG_02         float64
# CATEG_03         float64
# CATEG_04         float64
# CATEG_05         float64
# CATEG_06         float64
# CATEG_07         float64
# CATEG_08         float64
# CATEG_09         float64
# CATEG_10         float64
# CATEG_11         float64
# CATEG_12         float64
# CATEG_13         float64
# CATEG_14         float64
# CATEG_15         float64
# CATEG_16         float64
# mes_cont         float64
# cod_ap            object
# cod_municipio     object
# feature_01        object
# feature_02        object
# feature_03          bool
# feature_04       float64
# feature_05        object
# feature_06         int64
# feature_07       float64
# feature_08       float64
# feature_09       float64
# feature_10       float64
# feature_11        object
# feature_12        object
# feature_13       float64
# feature_14       float64
# feature_15       float64
# feature_16       float64
# feature_17       float64
# feature_18       float64
# renda_media      float64
# dtype: object

# %%
# estado

cod_estado = faturamento['cod_municipio'].astype('str').str[:2]
cod_estado = cod_estado.replace({'11' : 'RO', '12' : 'AC', '13' : 'AM', '14' : 'RR', '15' : 'PA',
                                 '16' : 'AP', '17' : 'TO', '21' : 'MA', '22' : 'PI', '23' : 'CE',
                                 '24' : 'RN', '25' : 'PB', '26' : 'PE', '27' : 'AL', '28' : 'SE',
                                 '29' : 'BA', '31' : 'MG', '32' : 'ES', '33' : 'RJ', '35' : 'SP',
                                 '41' : 'PR', '42' : 'SC', '43' : 'RS', '50' : 'MS', '51' : 'MT',
                                 '52' : 'GO', '53' : 'DF'})
faturamento['estado'] =  cod_estado

# regiao 

cod_regiao = faturamento['estado'].astype('str').str[:2]
cod_regiao = cod_regiao.replace({'RO' : 'NT', 'AC' : 'NT', 'AM' : 'NT', 'RR' : 'NT', 'PA' : 'NT',
                                 'AP' : 'NT', 'TO' : 'NT', 'MA' : 'NE', 'PI' : 'NE', 'CE' : 'NE',
                                 'RN' : 'NE', 'PB' : 'NE', 'PE' : 'NE', 'AL' : 'NE', 'SE' : 'NE',
                                 'BA' : 'NE', 'MG' : 'SD', 'ES' : 'SD', 'RJ' : 'SD', 'PR' : 'SU',
                                 'SC' : 'SU', 'RS' : 'SU', 'MS' : 'CO', 'MT' : 'CO', 'MS' : 'CO',
                                 'GO' : 'CO', 'DF' : 'CO'})
faturamento['regiao'] =  cod_regiao

# %%
faturamento.shape[0]
# Out:
# 73644

# %%
faturamento.head(15)
# Out:
#    cod_loja   ano mes     qtde     receita  CATEG_01  CATEG_02  CATEG_03  \
# 0         1  2016   1  13034.0   441833.37     301.0     137.0    1469.0
# 1         1  2016   2  11411.0   395340.22     187.0     193.0    1579.0
# 2         1  2016   3  15030.0   587810.18     242.0      71.0    1935.0
# 3         1  2016   4  12726.0   534618.84     104.0      74.0    1466.0
# 4         1  2016   5  13978.0   595477.92     100.0      84.0    1576.0
# 5         1  2016   6  14693.0   589947.05     108.0      96.0    1726.0
# 6         1  2016   7  13570.0   563814.03     111.0      90.0    1553.0
# 7         1  2016   8  13889.0   625181.36      86.0      81.0    1667.0
# 8         1  2016   9  13309.0   583509.12     148.0      90.0    1426.0
# 9         1  2016  10  14709.0   611797.30     147.0      79.0    1702.0
# 10        1  2016  11  19162.0   876921.63     102.0      75.0    1777.0
# 11        1  2016  12  26963.0  1257613.00     110.0     100.0    2294.0
# 12        1  2017   1  10065.0   404108.77     114.0     105.0    1508.0
# 13        1  2017   2  11107.0   483610.18      74.0      89.0    1917.0
# 14        1  2017   3  13958.0   626291.59     125.0      95.0    2417.0
#
#     CATEG_04  CATEG_05  ...  feature_12  feature_13  feature_14  feature_15  \
# 0      251.0    1155.0  ...         NaN         NaN         NaN         NaN
# 1      215.0    1213.0  ...         NaN         NaN         NaN         NaN
# 2      280.0    1460.0  ...         NaN         NaN         NaN         NaN
# 3      304.0    1356.0  ...         NaN         NaN         NaN         NaN
# 4      308.0    1777.0  ...         NaN         NaN         NaN         NaN
# 5      327.0    1599.0  ...         NaN         NaN         NaN         NaN
# 6      325.0    1329.0  ...         NaN         NaN         NaN         NaN
# 7      504.0    1238.0  ...         NaN         NaN         NaN         NaN
# 8      295.0    1374.0  ...         NaN         NaN         NaN         NaN
# 9      315.0    1983.0  ...         NaN         NaN         NaN         NaN
# 10     391.0    2913.0  ...         NaN         NaN         NaN         NaN
# 11     745.0    4768.0  ...         NaN         NaN         NaN         NaN
# 12     225.0    1310.0  ...         NaN         NaN         NaN         NaN
# 13     258.0    1437.0  ...         NaN         NaN         NaN         NaN
# 14     311.0    1846.0  ...         NaN         NaN         NaN         NaN
#
#     feature_16  feature_17  feature_18  renda_media  estado  regiao
# 0          NaN         NaN         NaN      1429.93      PR      SU
# 1          NaN         NaN         NaN      1429.93      PR      SU
# 2          NaN         NaN         NaN      1429.93      PR      SU
# 3          NaN         NaN         NaN      1429.93      PR      SU
# 4          NaN         NaN         NaN      1429.93      PR      SU
# 5          NaN         NaN         NaN      1429.93      PR      SU
# 6          NaN         NaN         NaN      1429.93      PR      SU
# 7          NaN         NaN         NaN      1429.93      PR      SU
# 8          NaN         NaN         NaN      1429.93      PR      SU
# 9          NaN         NaN         NaN      1429.93      PR      SU
# 10         NaN         NaN         NaN      1429.93      PR      SU
# 11         NaN         NaN         NaN      1429.93      PR      SU
# 12         NaN         NaN         NaN      1429.93      PR      SU
# 13         NaN         NaN         NaN      1429.93      PR      SU
# 14         NaN         NaN         NaN      1429.93      PR      SU
#
# [15 rows x 45 columns]

# %%
localidades = pd.read_csv('localidades.csv', sep=';', encoding='latin1')

# %%
localidades.head(10)
# Out:
#       CD_GEOCODIGO    TIPO   CD_GEOCODBA        NM_BAIRRO  CD_GEOCODSD  \
# 0  110001505000001  URBANO  1.100015e+11          Redondo  11000150500
# 1  110001515000001  URBANO           NaN              NaN  11000151500
# 2  110001520000001  URBANO           NaN              NaN  11000152000
# 3  110001525000001  URBANO           NaN              NaN  11000152500
# 4  110001530000001  URBANO           NaN              NaN  11000153000
# 5  110001535000001  URBANO           NaN              NaN  11000153500
# 6  110002305000001  URBANO           NaN              NaN  11000230500
# 7  110003105000001  URBANO           NaN              NaN  11000310500
# 8  110003105000008   RURAL           NaN              NaN  11000310500
# 9  110004905000001  URBANO  1.100049e+11  Princesa Isabel  11000490500
#
#   NM_SUBDISTRITO  CD_GEOCODDS                NM_DISTRITO  CD_GEOCODMU  \
# 0            NaN    110001505      ALTA FLORESTA D'OESTE      1100015
# 1            NaN    110001515         FILADÉLFIA D'OESTE      1100015
# 2            NaN    110001520                IZIDOLÂNDIA      1100015
# 3            NaN    110001525         NOVA GEASE D'OESTE      1100015
# 4            NaN    110001530  ROLIM DE MOURA DO GUAPORÉ      1100015
# 5            NaN    110001535      SANTO ANTÔNIO D'OESTE      1100015
# 6            NaN    110002305                  ARIQUEMES      1100023
# 7            NaN    110003105                     CABIXI      1100031
# 8            NaN    110003105                     CABIXI      1100031
# 9            NaN    110004905                     CACOAL      1100049
#
#             NM_MUNICIPIO  ...            NM_MESO     NM_UF CD_NIVEL  \
# 0  ALTA FLORESTA D'OESTE  ...  LESTE RONDONIENSE  RONDÔNIA        1
# 1  ALTA FLORESTA D'OESTE  ...  LESTE RONDONIENSE  RONDÔNIA        2
# 2  ALTA FLORESTA D'OESTE  ...  LESTE RONDONIENSE  RONDÔNIA        2
# 3  ALTA FLORESTA D'OESTE  ...  LESTE RONDONIENSE  RONDÔNIA        2
# 4  ALTA FLORESTA D'OESTE  ...  LESTE RONDONIENSE  RONDÔNIA        2
# 5  ALTA FLORESTA D'OESTE  ...  LESTE RONDONIENSE  RONDÔNIA        2
# 6              ARIQUEMES  ...  LESTE RONDONIENSE  RONDÔNIA        1
# 7                 CABIXI  ...  LESTE RONDONIENSE  RONDÔNIA        1
# 8                 CABIXI  ...  LESTE RONDONIENSE  RONDÔNIA        3
# 9                 CACOAL  ...  LESTE RONDONIENSE  RONDÔNIA        1
#
#    CD_CATEGORIA  NM_CATEGORIA              NM_LOCALIDADE          LONG  \
# 0             5        CIDADE      ALTA FLORESTA D'OESTE   -61,9998239
# 1            15          VILA         FILADÉLFIA D'OESTE  -62,04389767
# 2            20          VILA                IZIDOLÂNDIA  -62,17554949
# 3            25          VILA         NOVA GEASE D'OESTE  -62,31865014
# 4            30          VILA  ROLIM DE MOURA DO GUAPORÉ  -62,27681227
# 5            35          VILA      SANTO ANTÔNIO D'OESTE  -62,10442834
# 6             5        CIDADE                  ARIQUEMES  -63,03326928
# 7             5        CIDADE                     CABIXI  -60,54431358
# 8             1       POVOADO          PLANALTO SÃO LUIZ  -60,41520649
# 9             5        CIDADE                     CACOAL  -61,44294421
#
#             LAT         ALT   GM_PONTO_sk
# 0   -11,9355403  337,735719  1J6+^YP=gnhf
# 1  -12,43723873  215,244429  1J6+gStX@d?>
# 2  -12,60141549  181,044807  1J6+gwlc:Gtp
# 3  -11,91979246  191,576571  1J6+^nhO?byf
# 4  -13,07980643  157,285277  1J6+Hn4dy6Y-
# 5  -12,08943882  407,707855  1J6+g2mLy)Tf
# 6  -9,908462867  138,688981  1J6{7^Xi:vOp
# 7  -13,49976346   236,06316  1J6+O_Y;K@z>
# 8  -13,37444677  264,992801  1J6+O+1hOWX-
# 9  -11,43386503  177,453547  1J6+_2d21Tif
#
# [10 rows x 21 columns]

# %%
localidades.dtypes
# Out:
# CD_GEOCODIGO        int64
# TIPO               object
# CD_GEOCODBA       float64
# NM_BAIRRO          object
# CD_GEOCODSD         int64
# NM_SUBDISTRITO     object
# CD_GEOCODDS         int64
# NM_DISTRITO        object
# CD_GEOCODMU         int64
# NM_MUNICIPIO       object
# NM_MICRO           object
# NM_MESO            object
# NM_UF              object
# CD_NIVEL            int64
# CD_CATEGORIA        int64
# NM_CATEGORIA       object
# NM_LOCALIDADE      object
# LONG               object
# LAT                object
# ALT                object
# GM_PONTO_sk        object
# dtype: object

# %%
localidades = localidades.rename(columns={'CD_GEOCODSD': 'cod_municipio', 'LONG': 'long', 'LAT': 'lat' })
localidades = localidades.loc[:, ['cod_municipio', 'long', 'lat']]
# cod muicipio vem com trailing zeros
localidades['cod_municipio'] = localidades['cod_municipio'].astype(str).str[:7]
localidades['lat'] = localidades['lat'].astype(str).str.translate({32:None, 44:46}).astype(float)
localidades['long'] = localidades['long'].astype(str).str.translate({32:None, 44:46}).astype(float)

# %%
localidades.head()
# Out:
#   cod_municipio       long        lat
# 0       1100015 -61.999824 -11.935540
# 1       1100015 -62.043898 -12.437239
# 2       1100015 -62.175549 -12.601415
# 3       1100015 -62.318650 -11.919792
# 4       1100015 -62.276812 -13.079806

# %%
# pegando a media de latitude e longitude das areas como aproximacao do muncipiio
localidades = localidades.groupby('cod_municipio').mean()
localidades.head()
# Out:
#                     long        lat
# cod_municipio
# 1100015       -62.153194 -12.343872
# 1100023       -63.033269  -9.908463
# 1100031       -60.479760 -13.437105
# 1100049       -61.312022 -11.225933
# 1100056       -60.818426 -13.195033

# %%
# latitude e longitude por municipio
faturamento = pd.merge(faturamento, localidades, on='cod_municipio', how='left')
faturamento.head()
# Out:
#   cod_loja   ano mes     qtde    receita  CATEG_01  CATEG_02  CATEG_03  \
# 0        1  2016   1  13034.0  441833.37     301.0     137.0    1469.0
# 1        1  2016   2  11411.0  395340.22     187.0     193.0    1579.0
# 2        1  2016   3  15030.0  587810.18     242.0      71.0    1935.0
# 3        1  2016   4  12726.0  534618.84     104.0      74.0    1466.0
# 4        1  2016   5  13978.0  595477.92     100.0      84.0    1576.0
#
#    CATEG_04  CATEG_05  ...  feature_14  feature_15  feature_16  feature_17  \
# 0     251.0    1155.0  ...         NaN         NaN         NaN         NaN
# 1     215.0    1213.0  ...         NaN         NaN         NaN         NaN
# 2     280.0    1460.0  ...         NaN         NaN         NaN         NaN
# 3     304.0    1356.0  ...         NaN         NaN         NaN         NaN
# 4     308.0    1777.0  ...         NaN         NaN         NaN         NaN
#
#    feature_18  renda_media  estado  regiao       long        lat
# 0         NaN      1429.93      PR      SU -49.170762 -25.589919
# 1         NaN      1429.93      PR      SU -49.170762 -25.589919
# 2         NaN      1429.93      PR      SU -49.170762 -25.589919
# 3         NaN      1429.93      PR      SU -49.170762 -25.589919
# 4         NaN      1429.93      PR      SU -49.170762 -25.589919
#
# [5 rows x 47 columns]

# %%
percent_missing = faturamento.isnull().sum() * 100 / len(faturamento)
missing_value_df = pd.DataFrame({'column_name': faturamento.columns,
                                 'percent_missing': percent_missing}).reset_index(drop=True)
missing_value_df
# Out:
#       column_name  percent_missing
# 0        cod_loja         0.000000
# 1             ano         0.000000
# 2             mes         0.000000
# 3            qtde         0.000000
# 4         receita         0.000000
# 5        CATEG_01         0.426376
# 6        CATEG_02        28.393352
# 7        CATEG_03         0.009505
# 8        CATEG_04         0.407365
# 9        CATEG_05         0.008147
# 10       CATEG_06         0.905709
# 11       CATEG_07         0.004074
# 12       CATEG_08         0.262072
# 13       CATEG_09         0.006789
# 14       CATEG_10         0.071968
# 15       CATEG_11         0.006789
# 16       CATEG_12         0.009505
# 17       CATEG_13         3.635055
# 18       CATEG_14         5.041823
# 19       CATEG_15        98.729021
# 20       CATEG_16        99.997284
# 21       mes_cont         0.000000
# 22         cod_ap         0.000000
# 23  cod_municipio         0.000000
# 24     feature_01        63.375156
# 25     feature_02         0.000000
# 26     feature_03         0.000000
# 27     feature_04         0.000000
# 28     feature_05         0.000000
# 29     feature_06         0.000000
# 30     feature_07         0.000000
# 31     feature_08         0.000000
# 32     feature_09         0.000000
# 33     feature_10         0.000000
# 34     feature_11        92.057737
# 35     feature_12        92.057737
# 36     feature_13        71.553691
# 37     feature_14        71.553691
# 38     feature_15        71.553691
# 39     feature_16        71.553691
# 40     feature_17        71.553691
# 41     feature_18        71.553691
# 42    renda_media        24.340068
# 43         estado         0.000000
# 44         regiao         0.000000
# 45           long         4.800119
# 46            lat         4.800119

# %%
# observacao importante : tem -1  em cod_ap, cod_municipio, regiao e estado. Por isso que aparece como se nao tivesse nenhum 
# missing value mas na vdd tem. Para substutui os missing values, samplear de uma gaussian fitada nos dados existentes uma boa?

# porem o fato de nao termos os dados diz algo a mais sobre essas lojas? tem relacao com a receita?
faturamento[faturamento['cod_ap'] == '-1'].sample(20)
# Out:
#       cod_loja   ano mes     qtde    receita  CATEG_01  CATEG_02  CATEG_03  \
# 16915      819  2017  12   1395.0   65015.07      22.0       2.0      62.0
# 40959     2008  2017   1   1476.0   83475.36       6.0       NaN      22.0
# 69242     3435  2016  11   1208.0   61473.78       1.0       1.0      73.0
# 43463     2133  2017   9   2887.0  110528.31      38.0       2.0     275.0
# 38791     1906  2016   3   1038.0   44140.89      14.0       NaN      48.0
# 17972      871  2016   1   1827.0   71116.92       9.0       3.0      39.0
# 37537     1836  2017   9   4078.0  151644.59     198.0      19.0     413.0
# 54596     2684  2017   2   6635.0  299298.63      31.0       NaN     334.0
# 49620     2439  2017  11  17885.0  894206.87      62.0       9.0     594.0
# 31393     1535  2017   6    478.0   23437.61       2.0       1.0      17.0
# 19756      958  2016   9    869.0   45479.49      14.0       NaN      85.0
# 43784     2149  2016   6   6292.0  253631.32      31.0       4.0     194.0
# 68356     3385  2016   5   1604.0   72666.89      28.0       NaN      33.0
# 39099     1920  2017  11   1391.0   61152.85      27.0       3.0      47.0
# 54425     2677  2016  11   1258.0   51355.65      13.0       1.0     105.0
# 59733     2936  2017   7   3296.0  154064.89      42.0       NaN     191.0
# 68094     3370  2017  11   2269.0  113910.27      15.0       NaN     124.0
# 15597      760  2016   2   4587.0  181704.19      36.0      27.0     308.0
# 72052     3602  2016  10    902.0   42645.25       4.0       NaN      43.0
# 43782     2149  2016   4   3916.0  179990.24      34.0       1.0     119.0
#
#        CATEG_04  CATEG_05  ...  feature_14  feature_15  feature_16  \
# 16915      11.0     171.0  ...         NaN         NaN         NaN
# 40959       8.0     142.0  ...         NaN         NaN         NaN
# 69242      10.0     163.0  ...         NaN         NaN         NaN
# 43463      43.0     568.0  ...         NaN         NaN         NaN
# 38791       3.0      93.0  ...         NaN         NaN         NaN
# 17972      12.0     209.0  ...         NaN         NaN         NaN
# 37537      60.0     628.0  ...        81.8        60.0        90.0
# 54596      99.0     913.0  ...        79.7       100.0        75.0
# 49620     105.0    1886.0  ...        92.5       100.0       100.0
# 31393       NaN      35.0  ...         NaN         NaN         NaN
# 19756      16.0     124.0  ...         NaN         NaN         NaN
# 43784     129.0     977.0  ...         NaN         NaN         NaN
# 68356      12.0     167.0  ...         NaN         NaN         NaN
# 39099      18.0     215.0  ...         NaN         NaN         NaN
# 54425      30.0     228.0  ...         NaN         NaN         NaN
# 59733      53.0     592.0  ...        95.6       100.0       100.0
# 68094      18.0     309.0  ...         NaN         NaN         NaN
# 15597      62.0     496.0  ...        83.8         0.0       100.0
# 72052       4.0     191.0  ...         NaN         NaN         NaN
# 43782      73.0     683.0  ...         NaN         NaN         NaN
#
#        feature_17  feature_18  renda_media  estado  regiao  long  lat
# 16915         NaN         NaN          NaN      -1      -1   NaN  NaN
# 40959         NaN         NaN          NaN      -1      -1   NaN  NaN
# 69242         NaN         NaN          NaN      -1      -1   NaN  NaN
# 43463         NaN         NaN          NaN      -1      -1   NaN  NaN
# 38791         NaN         NaN          NaN      -1      -1   NaN  NaN
# 17972         NaN         NaN          NaN      -1      -1   NaN  NaN
# 37537        94.9        89.9          NaN      -1      -1   NaN  NaN
# 54596        82.2        83.9          NaN      -1      -1   NaN  NaN
# 49620        99.6        98.6          NaN      -1      -1   NaN  NaN
# 31393         NaN         NaN          NaN      -1      -1   NaN  NaN
# 19756         NaN         NaN          NaN      -1      -1   NaN  NaN
# 43784         NaN         NaN          NaN      -1      -1   NaN  NaN
# 68356         NaN         NaN          NaN      -1      -1   NaN  NaN
# 39099         NaN         NaN          NaN      -1      -1   NaN  NaN
# 54425         NaN         NaN          NaN      -1      -1   NaN  NaN
# 59733        98.5        98.8          NaN      -1      -1   NaN  NaN
# 68094         NaN         NaN          NaN      -1      -1   NaN  NaN
# 15597        94.8        92.4          NaN      -1      -1   NaN  NaN
# 72052         NaN         NaN          NaN      -1      -1   NaN  NaN
# 43782         NaN         NaN          NaN      -1      -1   NaN  NaN
#
# [20 rows x 47 columns]

# %%
# EDA 
    # target variable and aproximate target variable (que a gente nao vai ter para submissao) 
    # pair anlysis
    # corr matrices
    # multicolinearity
    # etc

# %%
    # Obsevacoes:
        
        # Check Correlations and Multicolinearity in data
             # no  test set só teremos cod_loja, mes_cont, cod_ap, cod_municipio, renda_media, lat, long, num_lojas_regiao
             # sabemos que temos colinearidade forte entre cod_ap e renda_media, e de cod_municipio com lat e long 
             # tambem poderemos ter colinearidade forte de cod_loja com as features da loja
             # ferramentas: - teste VIF de multicolinearidade; chi-square test for independece, anova, pearson correlation

# %%
faturamento['cod_loja'].nunique()
# Out:
# 3130

# %%
print(faturamento.info())
print(faturamento.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73644 entries, 0 to 73643
# Data columns (total 47 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cod_loja       73644 non-null  object
#  1   ano            73644 non-null  object
#  2   mes            73644 non-null  object
#  3   qtde           73644 non-null  float64
#  4   receita        73644 non-null  float64
#  5   CATEG_01       73330 non-null  float64
#  6   CATEG_02       52734 non-null  float64
#  7   CATEG_03       73637 non-null  float64
#  8   CATEG_04       73344 non-null  float64
#  9   CATEG_05       73638 non-null  float64
#  10  CATEG_06       72977 non-null  float64
#  11  CATEG_07       73641 non-null  float64
#  12  CATEG_08       73451 non-null  float64
#  13  CATEG_09       73639 non-null  float64
#  14  CATEG_10       73591 non-null  float64
#  15  CATEG_11       73639 non-null  float64
#  16  CATEG_12       73637 non-null  float64
#  17  CATEG_13       70967 non-null  float64
#  18  CATEG_14       69931 non-null  float64
#  19  CATEG_15       936 non-null    float64
#  20  CATEG_16       2 non-null      float64
#  21  mes_cont       73644 non-null  float64
#  22  cod_ap         73644 non-null  object
#  23  cod_municipio  73644 non-null  object
#  24  feature_01     26972 non-null  object
#  25  feature_02     73644 non-null  object
#  26  feature_03     73644 non-null  bool
#  27  feature_04     73644 non-null  float64
#  28  feature_05     73644 non-null  object
#  29  feature_06     73644 non-null  int64
#  30  feature_07     73644 non-null  float64
#  31  feature_08     73644 non-null  float64
#  32  feature_09     73644 non-null  float64
#  33  feature_10     73644 non-null  float64
#  34  feature_11     5849 non-null   object
#  35  feature_12     5849 non-null   object
#  36  feature_13     20949 non-null  float64
#  37  feature_14     20949 non-null  float64
#  38  feature_15     20949 non-null  float64
#  39  feature_16     20949 non-null  float64
#  40  feature_17     20949 non-null  float64
#  41  feature_18     20949 non-null  float64
#  42  renda_media    55719 non-null  float64
#  43  estado         73644 non-null  object
#  44  regiao         73644 non-null  object
#  45  long           70109 non-null  float64
#  46  lat            70109 non-null  float64
# dtypes: bool(1), float64(33), int64(1), object(12)
# memory usage: 26.5+ MB
# None
# cod_loja          object
# ano               object
# mes               object
# qtde             float64
# receita          float64
# CATEG_01         float64
# CATEG_02         float64
# CATEG_03         float64
# CATEG_04         float64
# CATEG_05         float64
# CATEG_06         float64
# CATEG_07         float64
# CATEG_08         float64
# CATEG_09         float64
# CATEG_10         float64
# CATEG_11         float64
# CATEG_12         float64
# CATEG_13         float64
# CATEG_14         float64
# CATEG_15         float64
# CATEG_16         float64
# mes_cont         float64
# cod_ap            object
# cod_municipio     object
# feature_01        object
# feature_02        object
# feature_03          bool
# feature_04       float64
# feature_05        object
# feature_06         int64
# feature_07       float64
# feature_08       float64
# feature_09       float64
# feature_10       float64
# feature_11        object
# feature_12        object
# feature_13       float64
# feature_14       float64
# feature_15       float64
# feature_16       float64
# feature_17       float64
# feature_18       float64
# renda_media      float64
# estado            object
# regiao            object
# long             float64
# lat              float64
# dtype: object

# %%
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! parei aqui
# tem 167 lojas que tem meses faltando no ano
check_months = faturamento.groupby('cod_loja')['mes_cont'].nunique()
# tem que dar zero
print(len(check_months[check_months!=24]))
# Out:
# 167

# %%
faturamento['cod_loja'] = faturamento['cod_loja'].astype(int)
faturamento['ano'] = faturamento['ano'].astype(int)
faturamento['mes'] = faturamento['mes'].astype(int)
faturamento = faturamento.sort_values(by=['cod_loja', 'ano', 'mes'])
faturamento['cod_loja'] = faturamento['cod_loja'].astype(str)
faturamento['ano'] = faturamento['ano'].astype(str)
faturamento['mes'] = faturamento['mes'].astype(str)

# %%
faturamento[216:240]
# Out:
#     cod_loja   ano mes    qtde    receita  CATEG_01  CATEG_02  CATEG_03  \
# 216       11  2016   1  5925.0  205674.89      46.0       9.0     193.0
# 217       11  2016   2  3537.0  132605.15      28.0      29.0     114.0
# 218       11  2016   3  3319.0  146893.13      41.0       1.0     259.0
# 219       11  2016   4  3477.0  164956.17      47.0       3.0     132.0
# 220       11  2016   5  4380.0  212096.10      41.0       3.0     162.0
# 221       11  2016   6  5463.0  232642.90      39.0       5.0     172.0
# 222       11  2016   7  2798.0  135867.63      13.0       3.0      95.0
# 223       11  2016   8  3543.0  175400.47      20.0       5.0     140.0
# 224       11  2016   9  3405.0  156156.69      30.0       2.0     102.0
# 225       11  2016  10  3855.0  161709.32      35.0       1.0     144.0
# 226       11  2016  11  4734.0  197245.16      36.0       1.0     182.0
# 227       11  2016  12  7146.0  336761.36      49.0       4.0     174.0
# 228       11  2017   1  1870.0   90528.86      21.0       1.0      86.0
# 229       11  2017   5   570.0   26890.20       3.0       1.0      19.0
# 230       11  2017   6   395.0   18620.36       2.0       NaN      12.0
# 231       11  2017   7   249.0   10627.50       6.0       NaN       8.0
# 232       11  2017   8   310.0   14328.70       3.0       NaN      47.0
# 233       11  2017   9   343.0   12837.30       7.0       NaN      23.0
# 234       11  2017  10   371.0   12623.40       2.0       NaN      18.0
# 235       11  2017  11   634.0   23039.86       4.0       NaN      50.0
# 236       11  2017  12   737.0   30518.11       4.0       1.0      23.0
# 237       12  2016   1  1359.0   57952.38      18.0       4.0      65.0
# 238       12  2016   2   962.0   45710.35      18.0       8.0      58.0
# 239       12  2016   3  1161.0   56010.58      18.0       5.0     105.0
#
#      CATEG_04  CATEG_05  ...  feature_14  feature_15  feature_16  feature_17  \
# 216      70.0     501.0  ...         NaN         NaN         NaN         NaN
# 217      25.0     483.0  ...         NaN         NaN         NaN         NaN
# 218      31.0     431.0  ...         NaN         NaN         NaN         NaN
# 219      42.0     391.0  ...         NaN         NaN         NaN         NaN
# 220      42.0     649.0  ...         NaN         NaN         NaN         NaN
# 221      96.0     648.0  ...         NaN         NaN         NaN         NaN
# 222      47.0     334.0  ...         NaN         NaN         NaN         NaN
# 223      67.0     387.0  ...         NaN         NaN         NaN         NaN
# 224      36.0     484.0  ...         NaN         NaN         NaN         NaN
# 225      36.0     755.0  ...         NaN         NaN         NaN         NaN
# 226      56.0     829.0  ...         NaN         NaN         NaN         NaN
# 227      85.0    1178.0  ...         NaN         NaN         NaN         NaN
# 228      21.0     262.0  ...         NaN         NaN         NaN         NaN
# 229       3.0     157.0  ...         NaN         NaN         NaN         NaN
# 230       3.0      90.0  ...         NaN         NaN         NaN         NaN
# 231       2.0      31.0  ...         NaN         NaN         NaN         NaN
# 232       2.0      25.0  ...         NaN         NaN         NaN         NaN
# 233       3.0      37.0  ...         NaN         NaN         NaN         NaN
# 234       NaN      55.0  ...         NaN         NaN         NaN         NaN
# 235       3.0      74.0  ...         NaN         NaN         NaN         NaN
# 236       2.0     142.0  ...         NaN         NaN         NaN         NaN
# 237       8.0     119.0  ...         NaN         NaN         NaN         NaN
# 238       5.0     104.0  ...         NaN         NaN         NaN         NaN
# 239      13.0     106.0  ...         NaN         NaN         NaN         NaN
#
#      feature_18  renda_media  estado  regiao       long        lat
# 216         NaN       634.18      BA      NE -40.928223 -15.029682
# 217         NaN       634.18      BA      NE -40.928223 -15.029682
# 218         NaN       634.18      BA      NE -40.928223 -15.029682
# 219         NaN       634.18      BA      NE -40.928223 -15.029682
# 220         NaN       634.18      BA      NE -40.928223 -15.029682
# 221         NaN       634.18      BA      NE -40.928223 -15.029682
# 222         NaN       634.18      BA      NE -40.928223 -15.029682
# 223         NaN       634.18      BA      NE -40.928223 -15.029682
# 224         NaN       634.18      BA      NE -40.928223 -15.029682
# 225         NaN       634.18      BA      NE -40.928223 -15.029682
# 226         NaN       634.18      BA      NE -40.928223 -15.029682
# 227         NaN       634.18      BA      NE -40.928223 -15.029682
# 228         NaN       634.18      BA      NE -40.928223 -15.029682
# 229         NaN       634.18      BA      NE -40.928223 -15.029682
# 230         NaN       634.18      BA      NE -40.928223 -15.029682
# 231         NaN       634.18      BA      NE -40.928223 -15.029682
# 232         NaN       634.18      BA      NE -40.928223 -15.029682
# 233         NaN       634.18      BA      NE -40.928223 -15.029682
# 234         NaN       634.18      BA      NE -40.928223 -15.029682
# 235         NaN       634.18      BA      NE -40.928223 -15.029682
# 236         NaN       634.18      BA      NE -40.928223 -15.029682
# 237         NaN       862.91      BA      NE -44.342235 -13.267010
# 238         NaN       862.91      BA      NE -44.342235 -13.267010
# 239         NaN       862.91      BA      NE -44.342235 -13.267010
#
# [24 rows x 47 columns]

# %%
# datasets por loja 
# !!! tem lojas com meses faltando !!!

faturamentos_lojas = [ faturamento[24*i:24*i+24] for i in range(3131)]

print(faturamentos_lojas[9]['mes'])

#pegando lojas aleatorias
for i in range(5):
    rand = np.random.randint(0, 3131)
    #plot something
    fig, ax = plt.subplots()
    dataframe_loja = faturamentos_lojas[rand]
    #print(dataframe_loja)
    dataframe_loja['receita'][:12].reset_index(drop=True).plot(kind='line', ax=ax)
    dataframe_loja['receita'][12:].reset_index(drop=True).plot(kind='line', ax=ax)
    plt.show()
# Out:
# 216     1
# 217     2
# 218     3
# 219     4
# 220     5
# 221     6
# 222     7
# 223     8
# 224     9
# 225    10
# 226    11
# 227    12
# 228     1
# 229     5
# 230     6
# 231     7
# 232     8
# 233     9
# 234    10
# 235    11
# 236    12
# 237     1
# 238     2
# 239     3
# Name: mes, dtype: object

# %%
# analise global , media da receita das lojas ao longo do tempo

fig, ax = plt.subplots()
faturamanto_receita_media = faturamento.groupby('mes_cont')['receita'].mean().plot(kind='line', ax=ax)
plt.show()

# diferenca media entre os anos
faturamanto_receita_media_2016 = faturamanto_receita_media[:13]
faturamanto_receita_media_2017 = faturamanto_receita_media[13:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-f4c91554ce74> in <module>
#       6
#       7 # diferenca media entre os anos
# ----> 8 faturamanto_receita_media_2016 = faturamanto_receita_media[:13]
#       9 faturamanto_receita_media_2017 = faturamanto_receita_media[13:]
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
print('Lojas com geo desconhecido (-1) - média geral: {}'.format(faturamento[faturamento['cod_ap'] == '-1']['receita'].mean()))
print('Lojas com geo desconhecido - std geral: {}'.format(faturamento[faturamento['cod_ap'] == '-1']['receita'].std()))
print('----------------')
print('Lojas com geo conhecido - média geral: {}'.format(faturamento[faturamento['cod_ap'] != '-1']['receita'].mean()))
print('Lojas com geo conhecido - std geral: {}'.format(faturamento[faturamento['cod_ap'] != '-1']['receita'].std()))

# no conjunto de lojas -1 a media eh menor(mas parece bem pouco) e a variancia eh maior (talvez seja reelvante aqui)

# plotar as distribuicoes das receitas
receitas_geo_desconhecido = faturamento[faturamento['cod_ap'] == '-1']['receita']                                      
receitas_geo_conhecido = faturamento[faturamento['cod_ap'] != '-1']['receita']
# Out:
# Lojas com geo desconhecido (-1) - média geral: 121217.22053182461
# Lojas com geo desconhecido - std geral: 124688.15931468231
# ----------------
# Lojas com geo conhecido - média geral: 127442.05033504969
# Lojas com geo conhecido - std geral: 115429.49090320975

# %%
# rows which features from 13 to 18 are NaN

print('Lojas com NaN - média geral: {}'.format(faturamento[faturamento['feature_14'] != faturamento['feature_14']]['receita'].mean()))
print('Lojas com NaN - std geral: {}'.format(faturamento[faturamento['feature_14'] != faturamento['feature_14']]['receita'].std()))
print('----------------')
print('Lojas com features -  média geral:{}'.format(faturamento[faturamento['feature_14'] == faturamento['feature_14']]['receita'].mean()))
print('Lojas com features -  std geral:{}'.format(faturamento[faturamento['feature_14'] == faturamento['feature_14']]['receita'].std()))

#IMPORTANTE: Lojas que NaN nas features 13-18 tem receita mt menor!
# lojas quiosque talvez ?

# plotar as dsitribuicoes das receitas
# ver se as features estao influenciado a receita em faturamento_features_conhecidas (plotar)

receitas_features_NaN = faturamento[faturamento['feature_14'] != faturamento['feature_14']]['receita']
receitas_features_conhecidas = faturamento[faturamento['feature_14'] == faturamento['feature_14']]['receita']
# Out:
# Lojas com NaN - média geral: 97400.91578555839
# Lojas com NaN - std geral: 87824.21873415798
# ----------------
# Lojas com features -  média geral:201956.95852785333
# Lojas com features -  std geral:141409.3976894761

# %%
# influencia do numero de lojas na regiao
receita_regiao = faturamento.groupby('cod_ap').aggregate({'cod_loja': 'count','receita': 'mean'})
receita_regiao
# Out:
#                cod_loja        receita
# cod_ap
# -1                 3535  121217.220532
# 1100015001001        24   49665.950417
# 1100023003001        48  103779.700000
# 1100023003003        24  171428.721250
# 1100049003003        48  134509.871875
# ...                 ...            ...
# 5300108005042        48   92232.147500
# 5300108005043        24  202715.029167
# 5300108005045         2   24997.535000
# 5300108005046        24  163074.067917
# 5300108005050        48   54339.723542
#
# [2349 rows x 2 columns]

# %%
faturamento.to_csv('../processed/estrabico.csv')

# %%
# target-value - receita
# Tem duas temporadas mesmo de receita? uma no meio do ano e outra no final? 
    #-> daria pra colocar feature binaria pros meses do meio do ano
# o ano eh importante?
# testar sazonalidade de trimestre 
# sazonalidade da receita pode ser diferente para cada loja/regiao/categoria?
#a avliar isso para a media de todas as lojas, media de todas as lojas por regiao
#

# %%
# lojas grandes e lojas normais? Existem grupos de lojas?

# %%
# ver o comportamento de tipos de categorias presentes em cada mês

# %%
# como as categorias diferem em vendas e receita, e preço consequentemente?

# %%
# como preço da categorias varia durante o tempo?  Inflação importante?

# %%
# agr sobre as features das lojas

# features 7 e 8 bem parecidas?
# feature 9 parece ter dois grupos definidos, um de valores maiores e outro de valores menores , ver isso aí
# se features 13-18 sao influentes (pq sempre que elas aparecem, aparecem juntas), e um binario nao eh suficiente:
    # feature 15 parece ter valores discretos bem definidos, relacionada a fração de alguma coisa, tipo x/10 * 1000 -> substituir por números de 1 a 10? Dividir em grupos maiores?
    # fature 16 parece ser binária, 500 ou 1000, tratar como binária? ou 1 e 2 ?
    # features 13, 15, 16 tem os valores máximos = moda = 1000 , colocar features binárias para a presença de max?
    # feature 4 parece ter 2 grupos de valores: altos e normais. Talvez a questao de lojas grande e normais?

# %%
# automatic feature generayion pras features 1-12 (1 - 18 se as features  13-18 forem necessarias)

# %%
# clustering (K-means with PCA / t-SNE)

# %%
# EDA time series stuff (target variable time-series anlysis)
# Scipy 2019 tutorial

# %%
# Subsitute Missing Values

# %%
# Treat Outliers

# %%
# feature selection and engineering   
    # - sabemos de antemao a "cara" dos resultados no comeco de ano pq a easonalidade é mt forte e a variancia eh pequena para meses
    # - por isso seria bom dar uma forma dele copiar um pouco o ano passo, serve como uma proxy
    # - feature categorica que vale: 'Janeiro'; 'Fevereiro', 'Marco', 'Outros'
    
    # feature binaria que vale 1 se as features 13 a 18 estao presentes e 0 caso contrario
    
    # feature trimestral, comeco do ano, meio, final
    
    # feature de numero de lojas na mesmo cod_ap 
    
    # rotacionar latitude e longitude -> ajuda o modelo de arvore

# %%
# Encode Categorical Values
 # mean encodings (pure or rounded)

# %%
# build lag_dataset (with lag variables/sliding window)

# %%
# build receita_diff (differentiated time series of target value)
# plot it

# %%
# lembrandoque vamos fazer a previsao do mes seguinte só, depois repetimos o mesmo processo para os proximos meses
# train-test split 
# test set vai ser os ultimos 3 meses

# %%
# local cross validation function
     # lembrar de fazer sort by loja, pra fazer um stack das predictions [loja1: outubro2017 loja2: outubro2017 ...]
     # pq na hora de fazer as previsoes vamos empacotar desse jeito

# %%
# global cross validation function (next three months)
    # prediction
    # for i in range(1,3):
    # faturamento_i+1 = append do train_i com prediction_i
    # fazer tudo denovo
        # train test split deixando ultimos 3 meses de fora
        # treinar e cv modelos, treinar e cv ensemble, treinar modelos no dataset inteiro, treinar e cv ensemble no dataset inteiro
        # conseguir prediction_i 
        # append prediction_i no prediction_months
    # if cv=True 
        #call local cross validation and return cv 
    # else 
        #return prediction_months

# %%
# baseline model 1

# 0. Separar dataset para cada loja
# 1. Fazer 2017 - 2016
# 2. plotar 
# 3. fit and predict with ARIMA (diff = 1)
# 5. somar valor obtido com 2016
# 6. juntar as predictions
# 4. cv ARIMA

# %%
# baseline model 2

# 0. Separar dataset para cada loja
# 1. fit and predict with ARIMA (diff = 1 )
# 2. somar com valor do mes passado
# 3  juntar predtions
# 4. cv ARIMA

# %%
# xgboost with lag dataset

# %%
# train xgboost with lag dataset parameter tuning

# %%
# cv xgboost

# %%
# train other models
 # remember that with linear models we have to normalize variables

# %%
# other models parameter tuning (if needed)

# %%
# cv other models

# %%
# ensemble

# %%
# cv ensemble

# %%
# get parameters of ensemble, train models again on whole dataset

# %%
# make predictions wth global cv function (cv=False) for submission
